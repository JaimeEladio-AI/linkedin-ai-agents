# %% [markdown]
# # Comprobaciones rápidas
#
# Este notebook instala las dependencias del proyecto y ejecuta comprobaciones básicas:
# - `python -m py_compile main.py`
# - `pytest` (si existen tests)
#
# Úsalo en Google Colab abriendo: `File > Open notebook > GitHub` o mediante la URL directa.

# %%
# Clona el repositorio si no está disponible y navega a él
import os
if not os.path.exists('requirements.txt'):
    # !rm -rf linkedin-ai-agents
    # !git clone https://github.com/JaimeEladio-AI/linkedin-ai-agents.git
    # %cd linkedin-ai-agents
else:
    print('Repositorio ya cargado en el entorno actual')

# Instala las dependencias del proyecto
# !pip install -r requirements.txt

# %%
# Comprobar que main.py se compila sin errores
# !python -m py_compile main.py && echo "py_compile: OK" || echo "py_compile: FAILED"

# %%
# Ejecutar tests (si existen). No fallar el notebook por tests que fallen: se muestra el resultado
# !pytest -q || true
